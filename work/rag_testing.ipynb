# %% [markdown]
# #### データソースを準備

# %%
from trafilatura import fetch_url, extract

# 遊戯王カードwikiのページを取得
url = 'https://yugioh-wiki.net/index.php?%A1%DA%A5%A2%A5%EB%A5%D0%A5%B9%A4%CE%CD%EE%B0%FD%A1%DB'
filename = 'deck_albaz.txt'
document = fetch_url(url)

# extract()でテキストを抽出
text = extract(document)

# テキストをファイルに保存
if text is not None:
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(text)
else:
    print("No text could be extracted from the document.")

# %% [markdown]
# #### チャンク分割

# %%
from langchain.document_loaders import TextLoader

# テキストファイルを読み込む
loader = TextLoader(filename, encoding='utf-8')
raw_docs = loader.load()

from langchain.text_splitter import CharacterTextSplitter

# チャンク分割を定義
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=1000,
    chunk_overlap=0,
)

# 読み込んだテキストのチャンク分割を実行
docs = text_splitter.split_documents(raw_docs)

print(len(docs))
# Out:
# 9

# %% [markdown]
# #### embedding

# %%
import os
from dotenv import load_dotenv
from langchain.embeddings.openai import OpenAIEmbeddings

load_dotenv()

# OpenAIのEmbeddingモデルを定義
embeddings = OpenAIEmbeddings(deployment=os.environ["DEPLOYMENT_NAME_EMBEDDINGS"])

from langchain.vectorstores import Chroma

# Chromaベクトルストアを定義
db = Chroma.from_documents(docs, embeddings)

# %% [markdown]
# #### 回答

# %%
from langchain.chains import  RetrievalQA
from langchain.chat_models import AzureChatOpenAI
import re

retriever = db.as_retriever()

# チャットの組み立て
chat = AzureChatOpenAI(
    deployment_name=os.environ["DEPLOYMENT_NAME"],
    temperature=0
)

# RAGのためのchainを組み立て
rag_qa = RetrievalQA.from_chain_type(
    llm = chat,
    chain_type= "stuff",
    retriever = retriever,
    return_source_documents = True,
)

# 質問文のリストを作成
query_list = ["「アルバスの落胤」デッキのキーカードは？",
              "「アルバスの落胤」の攻は？",
              "「アルバスの落胤」デッキの弱点は？",
              "烙印融合のテキストを教えて",
              "「アルバスの落胤」デッキの派生デッキを3つ教えて",
              "「アルバスの落胤」デッキではリンクモンスターは何が採用される？",
              "「アルバスの落胤」デッキでよく使われるカウンター罠は？",
              "「アルバスの落胤」デッキの戦術は？",
              "「烙印融合」をサーチする方法を教えて",
              "「アルバスの落胤」デッキでは召喚権をどのモンスターに使う？",
              "「アルバスの落胤」デッキにティアラメンツを混ぜるメリットは？",
]

# LLMに渡すチャンクを格納する空リストを作成
context_list = []

# LLMからの回答を格納する空リストを作成
result_list = []

# rag_qaを回して、context_listとresult_listに選ばれたチャンクと回答を格納していく
for query in query_list:
    rag_result = rag_qa({"query": query})

    # contextを取得して、page_contentフィールドをcontext_listに追加に格納
    context = rag_result["source_documents"][0]
    context_list.append(context.page_content)

    # resultを取得して、result_listに格納
    result_list.append(rag_result["result"])

print("チャンクを表示")
print(*context_list, sep='\n++++++++++++\n')
print("*************")
print("回答を表示")
print(*result_list, sep='\n++++++++++++\n')
# Out:
# チャンクを表示
# 【アルバスの落胤】 †
# デッキの概要 †
# 自身と相手モンスターを素材にフィールド融合を行う《アルバスの落胤》を中心とした【正規融合】デッキ。
# 《アルバスの落胤》には、烙印を始めとする専用サポートや自身を名指し指定する融合モンスターが多く、それらを軸として構築していく。
# - 烙印カードの多くと相性が良い事もあり、その採用枚数も多くなりがちなので、デッキ名は【烙印】と称される事もある。
# なお、公式データベースのデッキ検索欄では、「登録カテゴリ」の欄に「アルバスの落胤」と「烙印」の両方が存在する。
# 《アルバスの落胤/Fallen of Albaz》
# 効果モンスター
# 星４/闇属性/ドラゴン族/攻1800/守 0
# このカード名の効果は１ターンに１度しか使用できない。
# (1)：このカードが召喚・特殊召喚に成功した場合、手札を１枚捨てて発動できる。
# 融合モンスターカードによって決められた、
# このカードを含む融合素材モンスターを自分・相手フィールドから墓地へ送り、
# その融合モンスター１体をＥＸデッキから融合召喚する。
# この効果で融合召喚する場合、このカード以外の自分フィールドのモンスターを融合素材にできない。
# 《氷剣竜ミラジェイド/Mirrorjade the Iceblade Dragon》
# 融合・効果モンスター
# 星８/闇属性/幻竜族/攻3000/守2500
# 「アルバスの落胤」＋融合・Ｓ・Ｘ・リンクモンスター
# (1)：「氷剣竜ミラジェイド」は自分フィールドに１体しか表側表示で存在できない。
# (2)：自分・相手ターンに１度、「アルバスの落胤」を融合素材とする融合モンスター１体をＥＸデッキから墓地へ送って発動できる。
# フィールドのモンスター１体を選んで除外する。
# ++++++++++++
# 《アルバスの落胤》は自身を融合素材にしなければならないため、効果にチェーンされて除去されると手札コストも含めて手痛い消費となる。
# 非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい。
# 手札自体を狙われるのもつらく、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがち。
# 相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネック。
# 採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性である。
# その他、全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意。
# 代表的なカード †
# 関連リンク †
# ++++++++++++
# 《アルバスの落胤》は自身を融合素材にしなければならないため、効果にチェーンされて除去されると手札コストも含めて手痛い消費となる。
# 非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい。
# 手札自体を狙われるのもつらく、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがち。
# 相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネック。
# 採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性である。
# その他、全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意。
# 代表的なカード †
# 関連リンク †
# ++++++++++++
# その他、烙印をサーチできる《デスピアの導化アルベル》、継続的に融合召喚可能な《烙印劇城デスピア》も採用しやすいカードであろう。
# デスピアモンスターは墓地効果を持つものも多い為、《アルバスの落胤》の手札コストにしやすい点も噛み合いが良い。
# 同じ闇属性の融合召喚を主軸に据えたデッキなので、融合召喚等のサポートを共有できる。
# 【捕食植物】は先述した《捕食植物ドラゴスタペリア》を始めとした融合素材に融合モンスターを要求する融合モンスターを擁しており、《烙印融合》でディスアドバンテージを抑えつつ融合モンスターを用意できる恩恵が大きい。
# また、《烙印竜アルビオン》の融合素材として《ステイセイラ・ロマリン》を使用すれば《捕食植物ビブリスプ》を墓地へ送る事ができるので、《烙印融合》が実質的な捕食植物のサーチ手段となる。
# 他には《烙印追放》もこの軸と相性が良く、《スターヴ・ヴェノム・プレデター・フュージョン・ドラゴン》の融合召喚の難易度を低減できる。
# 《アルバスの落胤》とのシナジーを最優先とし、他カテゴリ間のコンボに関係なく汎用的なカードを採用したデッキ。
# 特に何も考えず《アルバスの落胤》に纏わるストーリー場面カードを投入していくだけで自然とこのタイプになる。
# このデッキの弱点 †
# 【正規融合】全体に該当する弱点（融合召喚メタやエクストラデッキメタ等）に関してはあちらを参照。
# 固有の弱点で真っ先に懸念すべきは、《アルバスの落胤》の効果を無効化あるいは不発にされた場合のディスアドバンテージだろう。
# ++++++++++++
# 【アルバスの落胤】 †
# デッキの概要 †
# 自身と相手モンスターを素材にフィールド融合を行う《アルバスの落胤》を中心とした【正規融合】デッキ。
# 《アルバスの落胤》には、烙印を始めとする専用サポートや自身を名指し指定する融合モンスターが多く、それらを軸として構築していく。
# - 烙印カードの多くと相性が良い事もあり、その採用枚数も多くなりがちなので、デッキ名は【烙印】と称される事もある。
# なお、公式データベースのデッキ検索欄では、「登録カテゴリ」の欄に「アルバスの落胤」と「烙印」の両方が存在する。
# 《アルバスの落胤/Fallen of Albaz》
# 効果モンスター
# 星４/闇属性/ドラゴン族/攻1800/守 0
# このカード名の効果は１ターンに１度しか使用できない。
# (1)：このカードが召喚・特殊召喚に成功した場合、手札を１枚捨てて発動できる。
# 融合モンスターカードによって決められた、
# このカードを含む融合素材モンスターを自分・相手フィールドから墓地へ送り、
# その融合モンスター１体をＥＸデッキから融合召喚する。
# この効果で融合召喚する場合、このカード以外の自分フィールドのモンスターを融合素材にできない。
# 《氷剣竜ミラジェイド/Mirrorjade the Iceblade Dragon》
# 融合・効果モンスター
# 星８/闇属性/幻竜族/攻3000/守2500
# 「アルバスの落胤」＋融合・Ｓ・Ｘ・リンクモンスター
# (1)：「氷剣竜ミラジェイド」は自分フィールドに１体しか表側表示で存在できない。
# (2)：自分・相手ターンに１度、「アルバスの落胤」を融合素材とする融合モンスター１体をＥＸデッキから墓地へ送って発動できる。
# フィールドのモンスター１体を選んで除外する。
# ++++++++++++
# 【アルバスの落胤】 †
# デッキの概要 †
# 自身と相手モンスターを素材にフィールド融合を行う《アルバスの落胤》を中心とした【正規融合】デッキ。
# 《アルバスの落胤》には、烙印を始めとする専用サポートや自身を名指し指定する融合モンスターが多く、それらを軸として構築していく。
# - 烙印カードの多くと相性が良い事もあり、その採用枚数も多くなりがちなので、デッキ名は【烙印】と称される事もある。
# なお、公式データベースのデッキ検索欄では、「登録カテゴリ」の欄に「アルバスの落胤」と「烙印」の両方が存在する。
# 《アルバスの落胤/Fallen of Albaz》
# 効果モンスター
# 星４/闇属性/ドラゴン族/攻1800/守 0
# このカード名の効果は１ターンに１度しか使用できない。
# (1)：このカードが召喚・特殊召喚に成功した場合、手札を１枚捨てて発動できる。
# 融合モンスターカードによって決められた、
# このカードを含む融合素材モンスターを自分・相手フィールドから墓地へ送り、
# その融合モンスター１体をＥＸデッキから融合召喚する。
# この効果で融合召喚する場合、このカード以外の自分フィールドのモンスターを融合素材にできない。
# 《氷剣竜ミラジェイド/Mirrorjade the Iceblade Dragon》
# 融合・効果モンスター
# 星８/闇属性/幻竜族/攻3000/守2500
# 「アルバスの落胤」＋融合・Ｓ・Ｘ・リンクモンスター
# (1)：「氷剣竜ミラジェイド」は自分フィールドに１体しか表側表示で存在できない。
# (2)：自分・相手ターンに１度、「アルバスの落胤」を融合素材とする融合モンスター１体をＥＸデッキから墓地へ送って発動できる。
# フィールドのモンスター１体を選んで除外する。
# ++++++++++++
# 《アルバスの落胤》は自身を融合素材にしなければならないため、効果にチェーンされて除去されると手札コストも含めて手痛い消費となる。
# 非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい。
# 手札自体を狙われるのもつらく、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがち。
# 相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネック。
# 採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性である。
# その他、全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意。
# 代表的なカード †
# 関連リンク †
# ++++++++++++
# 《アルバスの落胤》は自身を融合素材にしなければならないため、効果にチェーンされて除去されると手札コストも含めて手痛い消費となる。
# 非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい。
# 手札自体を狙われるのもつらく、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがち。
# 相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネック。
# 採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性である。
# その他、全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意。
# 代表的なカード †
# 関連リンク †
# ++++++++++++
# その他、烙印をサーチできる《デスピアの導化アルベル》、継続的に融合召喚可能な《烙印劇城デスピア》も採用しやすいカードであろう。
# デスピアモンスターは墓地効果を持つものも多い為、《アルバスの落胤》の手札コストにしやすい点も噛み合いが良い。
# 同じ闇属性の融合召喚を主軸に据えたデッキなので、融合召喚等のサポートを共有できる。
# 【捕食植物】は先述した《捕食植物ドラゴスタペリア》を始めとした融合素材に融合モンスターを要求する融合モンスターを擁しており、《烙印融合》でディスアドバンテージを抑えつつ融合モンスターを用意できる恩恵が大きい。
# また、《烙印竜アルビオン》の融合素材として《ステイセイラ・ロマリン》を使用すれば《捕食植物ビブリスプ》を墓地へ送る事ができるので、《烙印融合》が実質的な捕食植物のサーチ手段となる。
# 他には《烙印追放》もこの軸と相性が良く、《スターヴ・ヴェノム・プレデター・フュージョン・ドラゴン》の融合召喚の難易度を低減できる。
# 《アルバスの落胤》とのシナジーを最優先とし、他カテゴリ間のコンボに関係なく汎用的なカードを採用したデッキ。
# 特に何も考えず《アルバスの落胤》に纏わるストーリー場面カードを投入していくだけで自然とこのタイプになる。
# このデッキの弱点 †
# 【正規融合】全体に該当する弱点（融合召喚メタやエクストラデッキメタ等）に関してはあちらを参照。
# 固有の弱点で真っ先に懸念すべきは、《アルバスの落胤》の効果を無効化あるいは不発にされた場合のディスアドバンテージだろう。
# ++++++++++++
# 【アルバスの落胤】 †
# デッキの概要 †
# 自身と相手モンスターを素材にフィールド融合を行う《アルバスの落胤》を中心とした【正規融合】デッキ。
# 《アルバスの落胤》には、烙印を始めとする専用サポートや自身を名指し指定する融合モンスターが多く、それらを軸として構築していく。
# - 烙印カードの多くと相性が良い事もあり、その採用枚数も多くなりがちなので、デッキ名は【烙印】と称される事もある。
# なお、公式データベースのデッキ検索欄では、「登録カテゴリ」の欄に「アルバスの落胤」と「烙印」の両方が存在する。
# 《アルバスの落胤/Fallen of Albaz》
# 効果モンスター
# 星４/闇属性/ドラゴン族/攻1800/守 0
# このカード名の効果は１ターンに１度しか使用できない。
# (1)：このカードが召喚・特殊召喚に成功した場合、手札を１枚捨てて発動できる。
# 融合モンスターカードによって決められた、
# このカードを含む融合素材モンスターを自分・相手フィールドから墓地へ送り、
# その融合モンスター１体をＥＸデッキから融合召喚する。
# この効果で融合召喚する場合、このカード以外の自分フィールドのモンスターを融合素材にできない。
# 《氷剣竜ミラジェイド/Mirrorjade the Iceblade Dragon》
# 融合・効果モンスター
# 星８/闇属性/幻竜族/攻3000/守2500
# 「アルバスの落胤」＋融合・Ｓ・Ｘ・リンクモンスター
# (1)：「氷剣竜ミラジェイド」は自分フィールドに１体しか表側表示で存在できない。
# (2)：自分・相手ターンに１度、「アルバスの落胤」を融合素材とする融合モンスター１体をＥＸデッキから墓地へ送って発動できる。
# フィールドのモンスター１体を選んで除外する。
# ++++++++++++
# 《アルバスの落胤》は自身を融合素材にしなければならないため、効果にチェーンされて除去されると手札コストも含めて手痛い消費となる。
# 非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい。
# 手札自体を狙われるのもつらく、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがち。
# 相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネック。
# 採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性である。
# その他、全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意。
# 代表的なカード †
# 関連リンク †
# *************
# 回答を表示
# 「アルバスの落胤」が「アルバスの落胤」デッキのキーカードです。このカードは自身と相手モンスターを素材にフィールド融合を行うことができ、専用サポートや自身を名指し指定する融合モンスターが多く、デッキの軸となっています。
# ++++++++++++
# 「アルバスの落胤」の攻撃力は1800です。
# ++++++++++++
# 「アルバスの落胤」デッキの弱点は、手札誘発や伏せカードによる妨害を受けやすいことや、手札自体を狙われること、相手がモンスターを積極的に出してこないデッキの場合、「アルバスの落胤」や「超融合」が腐りやすいこと、採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな「メタビート」や「エルドリッチ」などとの相性が悪いこと、全体的に闇属性主体の構築になりやすいため、闇属性メタにも要注意であることなどが挙げられます。
# ++++++++++++
# 「融合モンスターカードによって決められた融合素材モンスターを自分フィールド・墓地から選んで融合デッキに戻し、その融合モンスターカード１枚をエクストラデッキから融合召喚する。この効果で融合召喚したモンスターは、自分フィールドに存在する限り、以下の効果を得る。●１ターンに１度、自分の手札・デッキから「烙印」モンスターカード１枚を墓地へ送って発動できる。このカードの攻撃力はターン終了時まで、その「烙印」モンスターカード１枚の種類によって決まる数値分アップする。」
# ++++++++++++
# 申し訳ありませんが、この文脈からは「アルバスの落胤」デッキの派生デッキについての情報は提供されていません。
# ++++++++++++
# 記事にはリンクモンスターの具体的な採用カードについては触れられていませんでした。そのため、具体的な回答はできません。ただし、リンクモンスターは融合素材に含めることができるため、デッキ構築においては融合素材との相性やデッキの戦略に合わせて選択されることが一般的です。
# ++++++++++++
# 文章中には具体的なカウンター罠の名前は出ていませんが、「非公開情報の手札誘発や伏せカードによる妨害を極力受けない様に、対策カードを用意した上で効果の発動を行いたい」という記述があります。つまり、相手の手札誘発や伏せカードによる妨害を防ぐための対策カードが必要であることが示唆されています。具体的にどのカウンター罠が使われるかはデッキ構築やプレイヤーの好みによって異なるため、一概には言えません。
# ++++++++++++
# 「アルバスの落胤」デッキは、自身と相手モンスターを素材にフィールド融合を行うことができる《アルバスの落胤》を中心とした【正規融合】デッキです。デッキの戦術としては、烙印を始めとする専用サポートや自身を名指し指定する融合モンスターを軸として構築し、効果を発動する際には非公開情報の手札誘発や伏せカードによる妨害を極力受けないように対策カードを用意することが重要です。また、手札自体を狙われることもあるため、ハンデスをされると《アルバスの落胤》の為に残した烙印魔法・罠カードが落とされることになりがちです。相手がモンスターを積極的に出してこないデッキの場合、《アルバスの落胤》や《超融合》が腐りかねないのもネックです。採用するモンスターを最小限に絞りつつ、特殊召喚メタやモンスター効果メタも採用しがちな【メタビート】や【エルドリッチ】などは最悪の相性であるため、注意が必要です。全体的に闇属性主体の構築になりやすいため、《暗闇を吸い込むマジック・ミラー》などの闇属性メタにも要注意です。
# ++++++++++++
# 「烙印融合」をサーチする方法としては、「捕食植物キメラフレシア」や「デスピアの導化アルベル」、「烙印劇城デスピア」などのカードがあります。また、「烙印竜アルビオン」の融合素材として「ステイセイラ・ロマリン」を使用することで、「捕食植物ビブリスプ」を墓地へ送り、「烙印融合」を実質的な捕食植物のサーチ手段とすることもできます。
# ++++++++++++
# 「アルバスの落胤」デッキでは、相手の手札誘発や伏せカードによる妨害を極力受けないようにするため、召喚権はできるだけ自分の手札を温存できるようなモンスターに使うことが望ましいです。具体的には、手札を増やす効果を持つモンスターや、デッキの展開に必要なモンスターなどが適しています。
# ++++++++++++
# 提供された文脈には「ティアラメンツ」という言葉が見当たりません。回答することができず申し訳ありません。他に何か質問があればお答えします。
